# %%
import pandas as pd

# %%
original_df = pd.read_csv("../datasets/raw/Scats_Data_October_2006.csv", skiprows=[0])
original_df.head
# Out:
# <bound method NDFrame.head of       SCATS Number                         Location CD_MELWAY  NB_LATITUDE  \
# 0              970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 1              970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 2              970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 3              970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 4              970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# ...            ...                              ...       ...          ...
# 4187          4821      VICTORIA_ST W OF BURNLEY_ST   002HF02    -37.81296
# 4188          4821      VICTORIA_ST W OF BURNLEY_ST   002HF02    -37.81296
# 4189          4821      VICTORIA_ST W OF BURNLEY_ST   002HF02    -37.81296
# 4190          4821      VICTORIA_ST W OF BURNLEY_ST   002HF02    -37.81296
# 4191          4821      VICTORIA_ST W OF BURNLEY_ST   002HF02    -37.81296
#
#       NB_LONGITUDE  HF VicRoads Internal  VR Internal Stat  VR Internal Loc  \
# 0        145.09159                   249               182                1
# 1        145.09159                   249               182                1
# 2        145.09159                   249               182                1
# 3        145.09159                   249               182                1
# 4        145.09159                   249               182                1
# ...            ...                   ...               ...              ...
# 4187     145.00830                  6673              1513                7
# 4188     145.00830                  6673              1513                7
# 4189     145.00830                  6673              1513                7
# 4190     145.00830                  6673              1513                7
# 4191     145.00830                  6673              1513                7
#
#       NB_TYPE_SURVEY        Date  ...  V89  V90  V91  V92  V93  V94  V95  \
# 0                  1   1/10/2006  ...   66   81   50   59   47   29   34
# 1                  1   2/10/2006  ...  114   80   60   62   48   44   26
# 2                  1   3/10/2006  ...   86   93   90   73   57   29   40
# 3                  1   4/10/2006  ...  101  113   90   78   66   52   44
# 4                  1   5/10/2006  ...  113   99   91   61   55   49   36
# ...              ...         ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4187               1  27/10/2006  ...  103  122  124  117   99  108   88
# 4188               1  28/10/2006  ...  105  105  112   82   97  106  107
# 4189               1  29/10/2006  ...   76   66   64   77   60   49   45
# 4190               1  30/10/2006  ...   80   74   48   67   62   50   62
# 4191               1  31/10/2006  ...   87   74   87   75   63   51   54
#
#       Unnamed: 106  Unnamed: 107  Unnamed: 108
# 0              NaN           NaN           NaN
# 1              NaN           NaN           NaN
# 2              NaN           NaN           NaN
# 3              NaN           NaN           NaN
# 4              NaN           NaN           NaN
# ...            ...           ...           ...
# 4187           NaN           NaN           NaN
# 4188           NaN           NaN           NaN
# 4189           NaN           NaN           NaN
# 4190           NaN           NaN           NaN
# 4191           NaN           NaN           NaN
#
# [4192 rows x 109 columns]>

# %%
df_unique = original_df[["SCATS Number", "Location"]].drop_duplicates()

df_unique.head(15)
# Out:
#      SCATS Number                         Location
# 0             970  WARRIGAL_RD N of HIGH STREET_RD
# 31            970  HIGH STREET_RD E of WARRIGAL_RD
# 62            970  WARRIGAL_RD S of HIGH STREET_RD
# 93            970  HIGH STREET_RD W of WARRIGAL_RD
# 123          2000       WARRIGAL_RD N of TOORAK_RD
# 151          2000     BURWOOD_HWY E of WARRIGAL_RD
# 180          2000     WARRIGAL_RD S of BURWOOD_HWY
# 208          2000       TOORAK_RD W of WARRIGAL_RD
# 237          2200      UNION_RD N of MAROONDAH_HWY
# 268          2200      MAROONDAH_HWY E of UNION_RD
# 299          2200      UNION_RD S of MAROONDAH_HWY
# 330          2200      MAROONDAH_HWY W of UNION_RD
# 361          2820        EARL_ST SE of PRINCESS_ST
# 392          2820    PRINCESS_ST S of CHANDLER_HWY
# 422          2825        BURKE_RD S of EASTERN_FWY

# %%
import re

def parse_location(location):
    location = location.strip().upper()

    # Try more precise directions first
    directions = [" NW OF ", " NE OF ", " SW OF ", " SE OF ",
                  " N OF ", " S OF ", " E OF ", " W OF "]

    for dir_phrase in directions:
        if dir_phrase in location:
            parts = location.split(dir_phrase)
            if len(parts) == 2:
                main_road = parts[0].strip()
                cross_road = parts[1].strip()
                direction = dir_phrase.strip().split()[0]  # e.g., "NW"
                return main_road, direction, cross_road

    return None, None, None

# %%
df_unique[["Main Road", "Direction", "Cross Road"]] = df_unique["Location"].apply(
    lambda loc: pd.Series(parse_location(loc))
)


df_unique.head(15)
# Out:
#      SCATS Number                         Location       Main Road Direction  \
# 0             970  WARRIGAL_RD N of HIGH STREET_RD     WARRIGAL_RD         N
# 31            970  HIGH STREET_RD E of WARRIGAL_RD  HIGH STREET_RD         E
# 62            970  WARRIGAL_RD S of HIGH STREET_RD     WARRIGAL_RD         S
# 93            970  HIGH STREET_RD W of WARRIGAL_RD  HIGH STREET_RD         W
# 123          2000       WARRIGAL_RD N of TOORAK_RD     WARRIGAL_RD         N
# 151          2000     BURWOOD_HWY E of WARRIGAL_RD     BURWOOD_HWY         E
# 180          2000     WARRIGAL_RD S of BURWOOD_HWY     WARRIGAL_RD         S
# 208          2000       TOORAK_RD W of WARRIGAL_RD       TOORAK_RD         W
# 237          2200      UNION_RD N of MAROONDAH_HWY        UNION_RD         N
# 268          2200      MAROONDAH_HWY E of UNION_RD   MAROONDAH_HWY         E
# 299          2200      UNION_RD S of MAROONDAH_HWY        UNION_RD         S
# 330          2200      MAROONDAH_HWY W of UNION_RD   MAROONDAH_HWY         W
# 361          2820        EARL_ST SE of PRINCESS_ST         EARL_ST        SE
# 392          2820    PRINCESS_ST S of CHANDLER_HWY     PRINCESS_ST         S
# 422          2825        BURKE_RD S of EASTERN_FWY        BURKE_RD         S
#
#          Cross Road
# 0    HIGH STREET_RD
# 31      WARRIGAL_RD
# 62   HIGH STREET_RD
# 93      WARRIGAL_RD
# 123       TOORAK_RD
# 151     WARRIGAL_RD
# 180     BURWOOD_HWY
# 208     WARRIGAL_RD
# 237   MAROONDAH_HWY
# 268        UNION_RD
# 299   MAROONDAH_HWY
# 330        UNION_RD
# 361     PRINCESS_ST
# 392    CHANDLER_HWY
# 422     EASTERN_FWY

# %%
df_cleaned = df_unique.dropna(subset=["Main Road", "Cross Road"])

df_cleaned
# Out:
#       SCATS Number                         Location       Main Road Direction  \
# 0              970  WARRIGAL_RD N of HIGH STREET_RD     WARRIGAL_RD         N
# 31             970  HIGH STREET_RD E of WARRIGAL_RD  HIGH STREET_RD         E
# 62             970  WARRIGAL_RD S of HIGH STREET_RD     WARRIGAL_RD         S
# 93             970  HIGH STREET_RD W of WARRIGAL_RD  HIGH STREET_RD         W
# 123           2000       WARRIGAL_RD N of TOORAK_RD     WARRIGAL_RD         N
# ...            ...                              ...             ...       ...
# 4042          4812          SWAN_ST SW of MADDEN_GV         SWAN_ST        SW
# 4068          4821       WALMER_ST N OF VICTORIA_ST       WALMER_ST         N
# 4099          4821      VICTORIA_ST E OF BURNLEY_ST     VICTORIA_ST         E
# 4130          4821      BURNLEY_ST S OF VICTORIA_ST      BURNLEY_ST         S
# 4161          4821      VICTORIA_ST W OF BURNLEY_ST     VICTORIA_ST         W
#
#           Cross Road
# 0     HIGH STREET_RD
# 31       WARRIGAL_RD
# 62    HIGH STREET_RD
# 93       WARRIGAL_RD
# 123        TOORAK_RD
# ...              ...
# 4042       MADDEN_GV
# 4068     VICTORIA_ST
# 4099      BURNLEY_ST
# 4130     VICTORIA_ST
# 4161      BURNLEY_ST
#
# [139 rows x 5 columns]

# %%
grouped = df_cleaned.groupby("Main Road")

# %%
edges = []

for road, group in grouped:
    sorted_group = group.sort_values("Cross Road")  # Lexical sort for adjacency
    scats_list = sorted_group["SCATS Number"].tolist()

    for i in range(len(scats_list) - 1):
        edge = (scats_list[i], scats_list[i + 1])
        edges.append(edge)

# %%
print("Sample edges:", edges[:10])
print("Total edges:", len(edges))
# Out:
# Sample edges: [(4266, 4266), (4057, 4057), (4057, 3127), (3127, 3180), (3180, 4063), (4063, 4063), (4035, 3001), (3001, 3002), (3002, 3002), (3002, 3001)]
# Total edges: 92

# %%
edges = [tuple(edge) for edge in edges if edge[0] != edge[1]]
# stops same SCAT site on both ends

# %%
import json

with open("../datasets/processed/edges.json", "w") as f:
    json.dump(edges, f)
